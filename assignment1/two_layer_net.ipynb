# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
####################  ADDED ONLY FOR TEST  ####################
scores = net.loss(X)
W1, b1 = net.params['W1'], net.params['b1']
W2, b2 = net.params['W2'], net.params['b2']
N, D = X.shape

print X.shape
print W1.shape
print W2.shape
print b1.shape
print b2.shape

s1 = X.dot(W1) + b1
a1 = np.maximum(0, s1)
s2 = a1.dot(W2) + b2

print s2

####################  ADDED ONLY FOR TEST  ####################
# Out:
# (5, 4)
# (4, 10)
# (10, 3)
# (10,)
# (3,)
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]

# %%
scores = net.loss(X)
print 'Your scores:'
print scores
print
print 'correct scores:'
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print correct_scores
print

# The difference should be very small. We get < 1e-7
print 'Difference between your scores and correct scores:'
print np.sum(np.abs(scores - correct_scores))
# Out:
# Your scores:
# [[ 0.3644621   0.22911264  0.40642526]
#  [ 0.47590629  0.17217039  0.35192332]
#  [ 0.43035767  0.26164229  0.30800004]
#  [ 0.41583127  0.2983228   0.28584593]
#  [ 0.36328815  0.32279939  0.31391246]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 13.45686555

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
####################  ADDED ONLY FOR TEST  ####################

W1, b1 = net.params['W1'], net.params['b1']
W2, b2 = net.params['W2'], net.params['b2']
N, D = X.shape
C = W2.shape[1]
r = 0.1

s1 = X.dot(W1) + b1
a1 = np.maximum(0, s1); print a1.shape;
s2 = a1.dot(W2) + b2

fyi = s2.reshape(N * C, 1)[[i * C + l for i, l in enumerate(y)]].reshape(N)
L = -np.log(np.exp(fyi) / np.sum(np.exp(s2), 1))
loss = np.mean(L) + 0.5 * r * (np.sum(W1 * W1) + np.sum(W2 * W2))

print loss

####################  ADDED ONLY FOR TEST  ####################
# Out:
# (5, 10)
# 1.30378789133

# %%
loss, _ = net.loss(X, y, reg=0.1)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print 'Difference between your loss and correct loss:'
print np.sum(np.abs(loss - correct_loss))
# Out:
# Difference between your loss and correct loss:
# 1.79412040779e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
####################  ADDED ONLY FOR TEST  ####################

W1, b1 = net.params['W1'], net.params['b1']
W2, b2 = net.params['W2'], net.params['b2']
N, D = X.shape
C = W2.shape[1]
r = 0.1

a1 = X.dot(W1) + b1
s1 = np.maximum(0, a1)
a2 = s1.dot(W2) + b2

fyi = a2.reshape(N * C, 1)[[i * C + l for i, l in enumerate(y)]].reshape(N)  # fyi is the correct_scores
L = -np.log(np.exp(fyi) / np.sum(np.exp(a2), 1))
loss = np.mean(L) + 0.5 * r * (np.sum(W1 * W1) + np.sum(W2 * W2))

exp_scores = np.exp(a2)
probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True) # [N x K]

dscores = probs
dscores[range(N), y] = dscores[range(N), y] - 1
dscores = dscores / N

dW2 = np.dot(s1.T, dscores) + r * W2
db2 = np.sum(dscores, axis=0, keepdims=True)

ds1 = np.dot(dscores, W2.T)
da1 = ds1 * (a1 >= 0).astype(int)

dW1 = np.dot(X.T, da1) + r * W1
db1 = np.sum(da1, axis=0, keepdims=True)

####################  ADDED ONLY FOR TEST  ####################
# Out:
# (5, 3) (5, 1)

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.1)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.1)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print '%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name]))
# Out:
# W1 max relative error: 3.669857e-09
# W2 max relative error: 3.440708e-09
# b2 max relative error: 4.447677e-11
# b1 max relative error: 2.738421e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()

stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=1e-5,
            num_iters=100, batch_size=5, verbose=False)

print 'Final training loss: ', stats['loss_history'][-1]

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.0137571967664

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 300
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=4000, batch_size=200,
            learning_rate=1e-3, learning_rate_decay=0.95,
            reg=0.01, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print 'Validation accuracy: ', val_acc
# Out:
# iteration 0 / 4000: loss 2.302576
# iteration 100 / 4000: loss 1.863025
# iteration 200 / 4000: loss 1.696017
# iteration 300 / 4000: loss 1.574804
# iteration 400 / 4000: loss 1.632878
# iteration 500 / 4000: loss 1.504663
# iteration 600 / 4000: loss 1.430698
# iteration 700 / 4000: loss 1.388375
# iteration 800 / 4000: loss 1.480381
# iteration 900 / 4000: loss 1.467023
# iteration 1000 / 4000: loss 1.261002
# iteration 1100 / 4000: loss 1.345858
# iteration 1200 / 4000: loss 1.369023
# iteration 1300 / 4000: loss 1.333225
# iteration 1400 / 4000: loss 1.359844
# iteration 1500 / 4000: loss 1.282828
# iteration 1600 / 4000: loss 1.381339
# iteration 1700 / 4000: loss 1.286672
# iteration 1800 / 4000: loss 1.196471
# iteration 1900 / 4000: loss 1.159252
# iteration 2000 / 4000: loss 1.203390
# iteration 2100 / 4000: loss 1.211147
# iteration 2200 / 4000: loss 1.165859
# iteration 2300 / 4000: loss 1.106603
# iteration 2400 / 4000: loss 1.064590
# iteration 2500 / 4000: loss 1.145818
# iteration 2600 / 4000: loss 1.155871
# iteration 2700 / 4000: loss 1.083139
# iteration 2800 / 4000: loss 1.212462
# iteration 2900 / 4000: loss 1.169335
# iteration 3000 / 4000: loss 1.014193
# iteration 3100 / 4000: loss 1.018533
# iteration 3200 / 4000: loss 1.114075
# iteration 3300 / 4000: loss 1.059611
# iteration 3400 / 4000: loss 0.856449
# iteration 3500 / 4000: loss 1.086379
# iteration 3600 / 4000: loss 1.010038
# iteration 3700 / 4000: loss 1.008947
# iteration 3800 / 4000: loss 1.006197
# iteration 3900 / 4000: loss 1.053589
# Validation accuracy:  0.55

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
hidden_size_list = range(50, 130, 10)
learning_rate_list = [2e-3, 1e-3, 5e-4]
reg_list = [0.01, 0.1, 0.5, 1.0, 2.0]
# learning_rate_list = [1e-3]
# reg_list = [0.5]

results = {}
best_val = -1
best_net = None
best_stats = None

for hidden_size in hidden_size_list:
    for learning_rate in learning_rate_list:
        for reg in reg_list:
            net = TwoLayerNet(input_size, hidden_size, num_classes)

            # Train the network
            stats = net.train(X_train, y_train, X_val, y_val,
                        num_iters=2000, batch_size=200,
                        learning_rate=learning_rate, learning_rate_decay=0.95,
                        reg=reg, verbose=False)

            # Predict on the validation set
            val_acc = (net.predict(X_val) == y_val).mean()
            train_acc = (net.predict(X_train) == y_train).mean()
            print '[hidden_size={}, lr={}, reg={}] Training accurarcy: {}, Validation accuracy: {}'.format(
                hidden_size, learning_rate, reg, train_acc, val_acc)
            
            results[(hidden_size, learning_rate, reg)] = stats
            
            if val_acc > best_val:
                best_val = val_acc
                best_net = net
                best_stats = stats


#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# [hidden_size=50, lr=0.002, reg=0.01] Training accurarcy: 0.548020408163, Validation accuracy: 0.496
# [hidden_size=50, lr=0.002, reg=0.1] Training accurarcy: 0.543714285714, Validation accuracy: 0.507
# [hidden_size=50, lr=0.002, reg=0.5] Training accurarcy: 0.521714285714, Validation accuracy: 0.499
# [hidden_size=50, lr=0.002, reg=1.0] Training accurarcy: 0.500551020408, Validation accuracy: 0.497
# [hidden_size=50, lr=0.002, reg=2.0] Training accurarcy: 0.479571428571, Validation accuracy: 0.448
# [hidden_size=50, lr=0.001, reg=0.01] Training accurarcy: 0.538591836735, Validation accuracy: 0.505
# [hidden_size=50, lr=0.001, reg=0.1] Training accurarcy: 0.536653061224, Validation accuracy: 0.48
# [hidden_size=50, lr=0.001, reg=0.5] Training accurarcy: 0.524857142857, Validation accuracy: 0.488
# [hidden_size=50, lr=0.001, reg=1.0] Training accurarcy: 0.509489795918, Validation accuracy: 0.48
# [hidden_size=50, lr=0.001, reg=2.0] Training accurarcy: 0.490081632653, Validation accuracy: 0.471
# [hidden_size=50, lr=0.0005, reg=0.01] Training accurarcy: 0.498020408163, Validation accuracy: 0.487
# [hidden_size=50, lr=0.0005, reg=0.1] Training accurarcy: 0.499530612245, Validation accuracy: 0.482
# [hidden_size=50, lr=0.0005, reg=0.5] Training accurarcy: 0.495551020408, Validation accuracy: 0.485
# [hidden_size=50, lr=0.0005, reg=1.0] Training accurarcy: 0.483795918367, Validation accuracy: 0.454
# [hidden_size=50, lr=0.0005, reg=2.0] Training accurarcy: 0.471551020408, Validation accuracy: 0.468
# [hidden_size=60, lr=0.002, reg=0.01] Training accurarcy: 0.564591836735, Validation accuracy: 0.489
# [hidden_size=60, lr=0.002, reg=0.1] Training accurarcy: 0.519265306122, Validation accuracy: 0.487
# [hidden_size=60, lr=0.002, reg=0.5] Training accurarcy: 0.520346938776, Validation accuracy: 0.494
# [hidden_size=60, lr=0.002, reg=1.0] Training accurarcy: 0.508448979592, Validation accuracy: 0.48
# [hidden_size=60, lr=0.002, reg=2.0] Training accurarcy: 0.472551020408, Validation accuracy: 0.465
# [hidden_size=60, lr=0.001, reg=0.01] Training accurarcy: 0.543857142857, Validation accuracy: 0.506
# [hidden_size=60, lr=0.001, reg=0.1] Training accurarcy: 0.543489795918, Validation accuracy: 0.479
# [hidden_size=60, lr=0.001, reg=0.5] Training accurarcy: 0.528979591837, Validation accuracy: 0.483
# [hidden_size=60, lr=0.001, reg=1.0] Training accurarcy: 0.515551020408, Validation accuracy: 0.49
# [hidden_size=60, lr=0.001, reg=2.0] Training accurarcy: 0.494469387755, Validation accuracy: 0.48
# [hidden_size=60, lr=0.0005, reg=0.01] Training accurarcy: 0.504734693878, Validation accuracy: 0.493
# [hidden_size=60, lr=0.0005, reg=0.1] Training accurarcy: 0.505346938776, Validation accuracy: 0.492
# [hidden_size=60, lr=0.0005, reg=0.5] Training accurarcy: 0.497836734694, Validation accuracy: 0.492
# [hidden_size=60, lr=0.0005, reg=1.0] Training accurarcy: 0.491897959184, Validation accuracy: 0.474
# [hidden_size=60, lr=0.0005, reg=2.0] Training accurarcy: 0.476163265306, Validation accuracy: 0.46
# [hidden_size=70, lr=0.002, reg=0.01] Training accurarcy: 0.564020408163, Validation accuracy: 0.507
# [hidden_size=70, lr=0.002, reg=0.1] Training accurarcy: 0.536326530612, Validation accuracy: 0.487
# [hidden_size=70, lr=0.002, reg=0.5] Training accurarcy: 0.526020408163, Validation accuracy: 0.49
# [hidden_size=70, lr=0.002, reg=1.0] Training accurarcy: 0.517816326531, Validation accuracy: 0.483
# [hidden_size=70, lr=0.002, reg=2.0] Training accurarcy: 0.484836734694, Validation accuracy: 0.479
# [hidden_size=70, lr=0.001, reg=0.01] Training accurarcy: 0.547816326531, Validation accuracy: 0.504
# [hidden_size=70, lr=0.001, reg=0.1] Training accurarcy: 0.551428571429, Validation accuracy: 0.503
# [hidden_size=70, lr=0.001, reg=0.5] Training accurarcy: 0.525857142857, Validation accuracy: 0.5
# [hidden_size=70, lr=0.001, reg=1.0] Training accurarcy: 0.52287755102, Validation accuracy: 0.488
# [hidden_size=70, lr=0.001, reg=2.0] Training accurarcy: 0.50187755102, Validation accuracy: 0.486
# [hidden_size=70, lr=0.0005, reg=0.01] Training accurarcy: 0.512714285714, Validation accuracy: 0.473
# [hidden_size=70, lr=0.0005, reg=0.1] Training accurarcy: 0.510693877551, Validation accuracy: 0.489
# [hidden_size=70, lr=0.0005, reg=0.5] Training accurarcy: 0.501204081633, Validation accuracy: 0.48
# [hidden_size=70, lr=0.0005, reg=1.0] Training accurarcy: 0.495367346939, Validation accuracy: 0.481
# [hidden_size=70, lr=0.0005, reg=2.0] Training accurarcy: 0.478020408163, Validation accuracy: 0.456
# [hidden_size=80, lr=0.002, reg=0.01] Training accurarcy: 0.564326530612, Validation accuracy: 0.501
# [hidden_size=80, lr=0.002, reg=0.1] Training accurarcy: 0.565693877551, Validation accuracy: 0.496
# [hidden_size=80, lr=0.002, reg=0.5] Training accurarcy: 0.536, Validation accuracy: 0.507
# [hidden_size=80, lr=0.002, reg=1.0] Training accurarcy: 0.502693877551, Validation accuracy: 0.461
# [hidden_size=80, lr=0.002, reg=2.0] Training accurarcy: 0.493367346939, Validation accuracy: 0.479
# [hidden_size=80, lr=0.001, reg=0.01] Training accurarcy: 0.556408163265, Validation accuracy: 0.512
# [hidden_size=80, lr=0.001, reg=0.1] Training accurarcy: 0.544244897959, Validation accuracy: 0.497
# [hidden_size=80, lr=0.001, reg=0.5] Training accurarcy: 0.537387755102, Validation accuracy: 0.495
# [hidden_size=80, lr=0.001, reg=1.0] Training accurarcy: 0.522244897959, Validation accuracy: 0.498
# [hidden_size=80, lr=0.001, reg=2.0] Training accurarcy: 0.502081632653, Validation accuracy: 0.479
# [hidden_size=80, lr=0.0005, reg=0.01] Training accurarcy: 0.511693877551, Validation accuracy: 0.484
# [hidden_size=80, lr=0.0005, reg=0.1] Training accurarcy: 0.510326530612, Validation accuracy: 0.491
# [hidden_size=80, lr=0.0005, reg=0.5] Training accurarcy: 0.500714285714, Validation accuracy: 0.476
# [hidden_size=80, lr=0.0005, reg=1.0] Training accurarcy: 0.498408163265, Validation accuracy: 0.483
# [hidden_size=80, lr=0.0005, reg=2.0] Training accurarcy: 0.481612244898, Validation accuracy: 0.47
# [hidden_size=90, lr=0.002, reg=0.01] Training accurarcy: 0.543836734694, Validation accuracy: 0.456
# [hidden_size=90, lr=0.002, reg=0.1] Training accurarcy: 0.578653061224, Validation accuracy: 0.519
# [hidden_size=90, lr=0.002, reg=0.5] Training accurarcy: 0.558653061224, Validation accuracy: 0.508
# [hidden_size=90, lr=0.002, reg=1.0] Training accurarcy: 0.516040816327, Validation accuracy: 0.478
# [hidden_size=90, lr=0.002, reg=2.0] Training accurarcy: 0.492816326531, Validation accuracy: 0.464
# [hidden_size=90, lr=0.001, reg=0.01] Training accurarcy: 0.559408163265, Validation accuracy: 0.51
# [hidden_size=90, lr=0.001, reg=0.1] Training accurarcy: 0.559489795918, Validation accuracy: 0.518
# [hidden_size=90, lr=0.001, reg=0.5] Training accurarcy: 0.546244897959, Validation accuracy: 0.503
# [hidden_size=90, lr=0.001, reg=1.0] Training accurarcy: 0.53106122449, Validation accuracy: 0.491
# [hidden_size=90, lr=0.001, reg=2.0] Training accurarcy: 0.498816326531, Validation accuracy: 0.477
# [hidden_size=90, lr=0.0005, reg=0.01] Training accurarcy: 0.511693877551, Validation accuracy: 0.477
# [hidden_size=90, lr=0.0005, reg=0.1] Training accurarcy: 0.51087755102, Validation accuracy: 0.476
# [hidden_size=90, lr=0.0005, reg=0.5] Training accurarcy: 0.507040816327, Validation accuracy: 0.483
# [hidden_size=90, lr=0.0005, reg=1.0] Training accurarcy: 0.500918367347, Validation accuracy: 0.49
# [hidden_size=90, lr=0.0005, reg=2.0] Training accurarcy: 0.479632653061, Validation accuracy: 0.476
# [hidden_size=100, lr=0.002, reg=0.01] Training accurarcy: 0.568551020408, Validation accuracy: 0.509
# [hidden_size=100, lr=0.002, reg=0.1] Training accurarcy: 0.559979591837, Validation accuracy: 0.483
# [hidden_size=100, lr=0.002, reg=0.5] Training accurarcy: 0.54787755102, Validation accuracy: 0.512
# [hidden_size=100, lr=0.002, reg=1.0] Training accurarcy: 0.513836734694, Validation accuracy: 0.464
# [hidden_size=100, lr=0.002, reg=2.0] Training accurarcy: 0.498816326531, Validation accuracy: 0.48
# [hidden_size=100, lr=0.001, reg=0.01] Training accurarcy: 0.567755102041, Validation accuracy: 0.512
# [hidden_size=100, lr=0.001, reg=0.1] Training accurarcy: 0.558755102041, Validation accuracy: 0.504
# [hidden_size=100, lr=0.001, reg=0.5] Training accurarcy: 0.549979591837, Validation accuracy: 0.517
# [hidden_size=100, lr=0.001, reg=1.0] Training accurarcy: 0.522979591837, Validation accuracy: 0.479
# [hidden_size=100, lr=0.001, reg=2.0] Training accurarcy: 0.504591836735, Validation accuracy: 0.48
# [hidden_size=100, lr=0.0005, reg=0.01] Training accurarcy: 0.513163265306, Validation accuracy: 0.496
# [hidden_size=100, lr=0.0005, reg=0.1] Training accurarcy: 0.517734693878, Validation accuracy: 0.483
# [hidden_size=100, lr=0.0005, reg=0.5] Training accurarcy: 0.505265306122, Validation accuracy: 0.484
# [hidden_size=100, lr=0.0005, reg=1.0] Training accurarcy: 0.497714285714, Validation accuracy: 0.483
# [hidden_size=100, lr=0.0005, reg=2.0] Training accurarcy: 0.481653061224, Validation accuracy: 0.468
# [hidden_size=110, lr=0.002, reg=0.01] Training accurarcy: 0.577244897959, Validation accuracy: 0.49
# [hidden_size=110, lr=0.002, reg=0.1] Training accurarcy: 0.571408163265, Validation accuracy: 0.517
# [hidden_size=110, lr=0.002, reg=0.5] Training accurarcy: 0.55487755102, Validation accuracy: 0.501
# [hidden_size=110, lr=0.002, reg=1.0] Training accurarcy: 0.52693877551, Validation accuracy: 0.498
# [hidden_size=110, lr=0.002, reg=2.0] Training accurarcy: 0.498775510204, Validation accuracy: 0.478
# [hidden_size=110, lr=0.001, reg=0.01] Training accurarcy: 0.563265306122, Validation accuracy: 0.523
# [hidden_size=110, lr=0.001, reg=0.1] Training accurarcy: 0.566591836735, Validation accuracy: 0.522
# [hidden_size=110, lr=0.001, reg=0.5] Training accurarcy: 0.548734693878, Validation accuracy: 0.516
# [hidden_size=110, lr=0.001, reg=1.0] Training accurarcy: 0.532448979592, Validation accuracy: 0.501
# [hidden_size=110, lr=0.001, reg=2.0] Training accurarcy: 0.502530612245, Validation accuracy: 0.489
# [hidden_size=110, lr=0.0005, reg=0.01] Training accurarcy: 0.518714285714, Validation accuracy: 0.487
# [hidden_size=110, lr=0.0005, reg=0.1] Training accurarcy: 0.514653061224, Validation accuracy: 0.492
# [hidden_size=110, lr=0.0005, reg=0.5] Training accurarcy: 0.510204081633, Validation accuracy: 0.492
# [hidden_size=110, lr=0.0005, reg=1.0] Training accurarcy: 0.496693877551, Validation accuracy: 0.476
# [hidden_size=110, lr=0.0005, reg=2.0] Training accurarcy: 0.48393877551, Validation accuracy: 0.477
# [hidden_size=120, lr=0.002, reg=0.01] Training accurarcy: 0.555142857143, Validation accuracy: 0.503
# [hidden_size=120, lr=0.002, reg=0.1] Training accurarcy: 0.586836734694, Validation accuracy: 0.523
# [hidden_size=120, lr=0.002, reg=0.5] Training accurarcy: 0.53812244898, Validation accuracy: 0.509
# [hidden_size=120, lr=0.002, reg=1.0] Training accurarcy: 0.519530612245, Validation accuracy: 0.49
# [hidden_size=120, lr=0.002, reg=2.0] Training accurarcy: 0.493959183673, Validation accuracy: 0.495
# [hidden_size=120, lr=0.001, reg=0.01] Training accurarcy: 0.571959183673, Validation accuracy: 0.529
# [hidden_size=120, lr=0.001, reg=0.1] Training accurarcy: 0.567571428571, Validation accuracy: 0.513
# [hidden_size=120, lr=0.001, reg=0.5] Training accurarcy: 0.543142857143, Validation accuracy: 0.516
# [hidden_size=120, lr=0.001, reg=1.0] Training accurarcy: 0.531489795918, Validation accuracy: 0.491
# [hidden_size=120, lr=0.001, reg=2.0] Training accurarcy: 0.511918367347, Validation accuracy: 0.486
# [hidden_size=120, lr=0.0005, reg=0.01] Training accurarcy: 0.520081632653, Validation accuracy: 0.498
# [hidden_size=120, lr=0.0005, reg=0.1] Training accurarcy: 0.519897959184, Validation accuracy: 0.487
# [hidden_size=120, lr=0.0005, reg=0.5] Training accurarcy: 0.510836734694, Validation accuracy: 0.484
# [hidden_size=120, lr=0.0005, reg=1.0] Training accurarcy: 0.504653061224, Validation accuracy: 0.479
# [hidden_size=120, lr=0.0005, reg=2.0] Training accurarcy: 0.483469387755, Validation accuracy: 0.473

# %%
# plt.subplot(2, 1, 1)
# plt.plot(best_stats['loss_history'])
# plt.title('Loss history')
# plt.xlabel('Iteration')
# plt.ylabel('Loss')

# plt.subplot(2, 1, 2)
# plt.plot(best_stats['train_acc_history'], label='train')
# plt.plot(best_stats['val_acc_history'], label='val')
# plt.title('Classification accuracy history')
# plt.xlabel('Epoch')
# plt.ylabel('Clasification accuracy')
# plt.show()

print best_val

# print results
# for k, r in results.items():
#     print k[0], r['train_acc_history'][-1], r['val_acc_history'][-1]
# Out:
# 0.529

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print 'Test accuracy: ', test_acc
# Out:
# Test accuracy:  0.545
